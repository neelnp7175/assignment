# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.22.1)
# Requirement already satisfied: six>=1.12.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: jax>=0.3.15 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.6)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: packaging in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: libclang>=13.0.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: setuptools in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.5 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.16.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/prajapatineel/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense, Flatten
import matplotlib.pyplot as plt

# %%
X_train = np.loadtxt('input.csv',delimiter = ',')
Y_train = np.loadtxt('labels.csv',delimiter = ',')

X_test = np.loadtxt('input_test.csv',delimiter=',')
Y_test = np.loadtxt('labels_test.csv',delimiter = ',')

# %%
print('shape of X_train : ',X_train.shape)
print('shape of Y_train : ',Y_train.shape)
print('shape of X_test : ',X_test.shape)
print('shape of Y_test : ',Y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print('shape of X_train : ',X_train.shape)
#       2 print('shape of Y_train : ',Y_train.shape)
#       3 print('shape of X_test : ',X_test.shape)
#
# NameError: name 'X_train' is not defined

# %%
X_train = X_train.reshape(len(X_train),100 ,100 , 3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100 ,100 , 3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train/255.0
X_test = X_test/255.0

# %%
print("shape of X_train : ",X_train.shape)
print("shape of Y_train : ",Y_train.shape)
print("shape of X_test : ",X_test.shape)
print("shape of Y_test : ",X_test.shape)
# Out:
# shape of X_train :  (2000, 100, 100, 3)
# shape of Y_train :  (2000, 1)
# shape of X_test :  (400, 100, 100, 3)
# shape of Y_test :  (400, 100, 100, 3)

# %%
X_train[1,:]
# Out:
# array([[[0.51372549, 0.50196078, 0.52941176],
#         [0.62745098, 0.61568627, 0.64313725],
#         [0.77647059, 0.75294118, 0.8       ],
#         ...,
#         [0.98039216, 0.97647059, 0.96862745],
#         [1.        , 1.        , 0.99215686],
#         [0.98039216, 0.97647059, 0.96078431]],
#
#        [[0.54901961, 0.5372549 , 0.56470588],
#         [0.49803922, 0.48627451, 0.51372549],
#         [0.47058824, 0.44705882, 0.48627451],
#         ...,
#         [0.98431373, 0.99215686, 0.98823529],
#         [0.99607843, 1.        , 0.99215686],
#         [0.99607843, 1.        , 0.98431373]],
#
#        [[0.8       , 0.79215686, 0.81176471],
#         [0.73333333, 0.7254902 , 0.74509804],
#         [0.57647059, 0.55686275, 0.58039216],
#         ...,
#         [0.97647059, 1.        , 1.        ],
#         [0.93333333, 0.96862745, 0.94901961],
#         [0.90980392, 0.94509804, 0.9254902 ]],
#
#        ...,
#
#        [[0.68235294, 0.71372549, 0.76470588],
#         [0.6745098 , 0.70588235, 0.75686275],
#         [0.69803922, 0.72941176, 0.77254902],
#         ...,
#         [0.34117647, 0.44705882, 0.38039216],
#         [0.29411765, 0.38823529, 0.3254902 ],
#         [0.31372549, 0.41176471, 0.3372549 ]],
#
#        [[0.65098039, 0.67843137, 0.74117647],
#         [0.64313725, 0.6745098 , 0.7254902 ],
#         [0.6745098 , 0.70588235, 0.75686275],
#         ...,
#         [0.30588235, 0.41568627, 0.32941176],
#         [0.28235294, 0.38039216, 0.29803922],
#         [0.30196078, 0.4       , 0.31764706]],
#
#        [[0.67843137, 0.70588235, 0.76862745],
#         [0.6745098 , 0.70196078, 0.76470588],
#         [0.68235294, 0.71372549, 0.76470588],
#         ...,
#         [0.24705882, 0.35686275, 0.27058824],
#         [0.24313725, 0.34117647, 0.25490196],
#         [0.27843137, 0.37647059, 0.29019608]]])

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx,:])
plt.show()

# %%
model = Sequential([
    Conv2D(32,(3,3),activation = 'relu',input_shape = (100, 100, 3)),
    MaxPooling2D((2,2)),
    
    Conv2D(32,(3,3),activation = 'relu'),
    MaxPooling2D((2,2)),
     
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(1, activation = 'sigmoid'),
          
])

# %%
model.compile(loss='binary_crossentropy',optimizer ='adam', metrics = ['accuracy'] )

# %%
model.fit(X_train,Y_train , epochs = 5 , batch_size = 64 )
# Out:
# Epoch 1/5
# 32/32 [==============================] - 38s 1s/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 2/5
# 32/32 [==============================] - 42s 1s/step - loss: 0.6932 - accuracy: 0.4890
# Epoch 3/5
# 32/32 [==============================] - 40s 1s/step - loss: 0.6932 - accuracy: 0.4810
# Epoch 4/5
# 32/32 [==============================] - 36s 1s/step - loss: 0.6932 - accuracy: 0.5000
# Epoch 5/5
# 32/32 [==============================] - 41s 1s/step - loss: 0.6932 - accuracy: 0.4860

# %%
model.evaluate(X_test,Y_test)
# Out:
# 13/13 [==============================] - 2s 123ms/step - loss: 0.6931 - accuracy: 0.5000
# [0.6931478381156921, 0.5]

# %%
idx2 = random.randint(0, len(Y_test))
plt.imshow(X_test[idx2,:])
plt.show()

y_pred = model.predict(X_test[idx2,:].reshape(1,100,100,3))
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# [[0.49943247]]

# %%
y_pred = y_pred > 0.5
if y_pred == 0:
    print("CAT")
else :
    print("DOG")
# Out:
# CAT
