# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([2,23])
y = np.array([0,50])
plt.plot (x,y)
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"*")
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"_")
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"+")
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"^")
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"")
plt.show()

# %%
x = np.array([3,30])
y = np.array([1,11])
plt.plot(x,y,"o")
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
u = np.array([3, 8, 4, 5, 9, 6])

plt.plot(u,"o:c",ms = 13)
plt.show()

# %%
s =np.array([3, 5, 6,7 ,8 ,2 ])
plt.plot(s,"+:m",ms = 30, mec = "k",mfc = "g")
plt.show()
